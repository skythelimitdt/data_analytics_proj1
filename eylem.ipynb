# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Take in all of our data and read it into pandas

world_energy_df = pd.read_csv("Resources/world_energy_consumption.csv")
world_energy_df
# Out:
#              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 22007       Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008       Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009       Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010       Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011       Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# ...

# %%
world_energy_df.columns.tolist()
# Out:
# ['country',
#  'year',
#  'iso_code',
#  'population',
#  'gdp',
#  'biofuel_cons_change_pct',
#  'biofuel_cons_change_twh',
#  'biofuel_cons_per_capita',
#  'biofuel_consumption',
#  'biofuel_elec_per_capita',
#  'biofuel_electricity',
#  'biofuel_share_elec',
#  'biofuel_share_energy',
#  'carbon_intensity_elec',
#  'coal_cons_change_pct',
#  'coal_cons_change_twh',
#  'coal_cons_per_capita',
#  'coal_consumption',
#  'coal_elec_per_capita',
#  'coal_electricity',
#  'coal_prod_change_pct',
#  'coal_prod_change_twh',
#  'coal_prod_per_capita',
#  'coal_production',
#  'coal_share_elec',
#  'coal_share_energy',
#  'electricity_demand',
#  'electricity_generation',
#  'electricity_share_energy',
#  'energy_cons_change_pct',
#  'energy_cons_change_twh',
#  'energy_per_capita',
#  'energy_per_gdp',
#  'fossil_cons_change_pct',
#  'fossil_cons_change_twh',
#  'fossil_elec_per_capita',
#  'fossil_electricity',
#  'fossil_energy_per_capita',
#  'fossil_fuel_consumption',
# ...

# %%
#Look at the data type for each of the column
pd.set_option("display.max_columns", None)
world_energy_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Data columns (total 129 columns):
#  #    Column                                        Dtype
# ---   ------                                        -----
#  0    country                                       object
#  1    year                                          int64
#  2    iso_code                                      object
#  3    population                                    float64
#  4    gdp                                           float64
#  5    biofuel_cons_change_pct                       float64
#  6    biofuel_cons_change_twh                       float64
#  7    biofuel_cons_per_capita                       float64
#  8    biofuel_consumption                           float64
#  9    biofuel_elec_per_capita                       float64
#  10   biofuel_electricity                           float64
#  11   biofuel_share_elec                            float64
# ...

# %%
# Display all rows with at least 1 missing data (WE CAN DELETE)
combined_conditions = world_energy_df[
                    world_energy_df.isna().any(axis=1) | (world_energy_df == '').any(axis=1) | (world_energy_df == 0).any(axis=1)]
combined_conditions
# Out:
#              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 22007       Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008       Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009       Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010       Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011       Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# ...

# %%
# Display the data count on each column in our data set
pd.set_option("display.max_columns", None)
count_result = world_energy_df.count()
count_result
# Out:
# country                   22012
# year                      22012
# iso_code                  16512
# population                18123
# gdp                       11113
#                           ...
# wind_elec_per_capita       7065
# wind_electricity           7996
# wind_energy_per_capita     4065
# wind_share_elec            6886
# wind_share_energy          4101
# Length: 129, dtype: int64

# %%
#Remove all rows that does not have any data which indicates those rows do not represent the countries
countries_world_energy_df=world_energy_df.dropna(subset=['iso_code'])
countries_world_energy_df
# Out:
#            country  year iso_code  population           gdp  \
# 23     Afghanistan  1900      AFG   4707744.0           NaN
# 24     Afghanistan  1901      AFG   4751177.0           NaN
# 25     Afghanistan  1902      AFG   4802500.0           NaN
# 26     Afghanistan  1903      AFG   4861833.0           NaN
# 27     Afghanistan  1904      AFG   4921891.0           NaN
# ...            ...   ...      ...         ...           ...
# 22007     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008     Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009     Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010     Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011     Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 23                         NaN                      NaN
# 24                         NaN                      NaN
# 25                         NaN                      NaN
# ...

# %%
filtered_countries=countries_world_energy_df.loc[(countries_world_energy_df["year"] >= 1970)] 
filtered_countries.head()
# Out:
#         country  year iso_code  population           gdp  \
# 93  Afghanistan  1970      AFG  10752973.0  1.581223e+10
# 94  Afghanistan  1971      AFG  11015853.0  1.577051e+10
# 95  Afghanistan  1972      AFG  11286753.0  1.317055e+10
# 96  Afghanistan  1973      AFG  11575308.0  1.356863e+10
# 97  Afghanistan  1974      AFG  11869881.0  1.430911e+10
#
#     biofuel_cons_change_pct  biofuel_cons_change_twh  biofuel_cons_per_capita  \
# 93                      NaN                      NaN                      NaN
# 94                      NaN                      NaN                      NaN
# 95                      NaN                      NaN                      NaN
# 96                      NaN                      NaN                      NaN
# 97                      NaN                      NaN                      NaN
#
#     biofuel_consumption  biofuel_elec_per_capita  biofuel_electricity  \
# 93                  NaN                      NaN                  NaN
# ...

# %%
# Display the 
pd.set_option("display.max_columns", None)
count_result = countries_world_energy_df.count()
count_result
# Out:
# country                   16512
# year                      16512
# iso_code                  16512
# population                16396
# gdp                       10870
#                           ...
# wind_elec_per_capita       6402
# wind_electricity           6402
# wind_energy_per_capita     3447
# wind_share_elec            5682
# wind_share_energy          2804
# Length: 129, dtype: int64

# %%
six_continents = world_energy_df.loc[
    (
        (world_energy_df["country"] == "Asia") |
        (world_energy_df["country"] == "Africa") |
        (world_energy_df["country"] == "Australia") |
        (world_energy_df["country"] == "Europe") |
        (world_energy_df["country"] == "North America") |
        (world_energy_df["country"] == "South America")
    ) & (world_energy_df["year"] >= 1970)  
]
six_continents
# Out:
#              country  year iso_code   population  gdp  \
# 215           Africa  1970      NaN  365450443.0  NaN
# 216           Africa  1971      NaN  375086296.0  NaN
# 217           Africa  1972      NaN  384930776.0  NaN
# 218           Africa  1973      NaN  395212420.0  NaN
# 219           Africa  1974      NaN  406069208.0  NaN
# ...              ...   ...      ...          ...  ...
# 18052  South America  2018      NaN  424740741.0  NaN
# 18053  South America  2019      NaN  428318218.0  NaN
# 18054  South America  2020      NaN  431530105.0  NaN
# 18055  South America  2021      NaN  434254167.0  NaN
# 18056  South America  2022      NaN  436816679.0  NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 215                        NaN                      NaN
# 216                        NaN                      NaN
# 217                        NaN                      NaN
# 218                        NaN                      NaN
# ...
